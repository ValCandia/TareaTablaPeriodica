# %% [markdown]
# # PROGRAMA TABLA PERIÓDICA DE LOS ELEMENTOS
# ## Estudiante: Valeria Avril Candia Zarco

# %% [markdown]
# #### El siguiente programa fue desarrollado para comprender aún más la tabla periódica y obtener datos de los 118 elementos

# %%
print("\n" + "="*50)
print("----------------------------------------------------")
print("----🧪🧪TABLA PERIÓDICA DE LOS ELEMENTOS🧪🧪------")
print("----------------------------------------------------")
print("")
print("="*50)

def volvermenu():
    opcion0 = input("\n Si desea volver al menú ingrese 1:")
    if opcion0 == "1":
        menu()
    else:
        print("Opción inválida")
        volvermenu()

def menu():
    
        print("1. ¿Qué es la tabla periódica?📖")
        print("2. ¿Cómo se divide la tabla?🧩")
        print("3. Explicación de los datos (recomendado antes de buscar la información de un elemento)📖")
        print("4. Buscar información de un elemento🔍")
        print("5. Salir🚪")
        
        opcion = input("\nElige una opción (1-4): ")
        
        if opcion == "1":
            mostrar_bienvenida()
            volvermenu()
        elif opcion == "2":
            explicar_division()
            volvermenu()
        elif opcion == "3":
            explicacion_datos()
            volvermenu()
        elif opcion == "4":
            buscar_elemento()
            volvermenu()
        elif opcion == "5":
            print("\n¡Gracias por usar la Tabla Periódica Interactiva!")
            print("Vuelve pronto para aprender más sobre química.")
            
        else:
            print("Opción no válida. Por favor elige del 1 al 4.")

def explicacion_datos():
    print("\n=== EXPLICACIÓN DE LOS DATOS DE LOS ELEMENTOS ===\n")
    print("A continuación se explica el significado de cada campo de información:\n")
    
    print("NOMBRE:")
    print("   - El nombre completo del elemento químico.")
    print("   - Ejemplo: 'Hidrógeno', 'Oxígeno', 'Hierro'")
    print("   - Es la forma estándar de referirse al elemento.\n")
    
    print("SÍMBOLO:")
    print("   - Representación abreviada internacional del elemento (1-2 letras).")
    print("   - La primera letra siempre es mayúscula, la segunda minúscula.")
    print("   - Ejemplos: 'H' (Hidrógeno), 'O' (Oxígeno), 'Fe' (Hierro)")
    print("   - Permite una identificación rápida y universal.\n")
    
    print("NÚMERO ATÓMICO (Z):")
    print("   - Número de protones en el núcleo del átomo.")
    print("   - Determina la identidad del elemento y su posición en la tabla periódica.")
    print("   - Ejemplo: El hidrógeno tiene Z=1, el helio Z=2")
    print("   - Es único para cada elemento y nunca cambia.\n")
    
    print("MASA ATÓMICA:")
    print("   - Peso promedio de los átomos del elemento")
    print("   - Se expresa en unidades de masa atómica unificada (u).")
    print("   - Ejemplo: El carbono tiene una masa atómica de ~12.01 u")
    print("   - Importante para cálculos estequiométricos (Ciencia que mide las proporciones cuantitativas o relaciones de masa de los elementos químicos que están implicados.\n")
    
    print("GRUPO:")
    print("   - Número de columna en la tabla periódica (1-18).")
    print("   - Elementos del mismo grupo tienen propiedades químicas similares.")
    print("   - Ejemplo: Grupo 1 = metales alcalinos, Grupo 17 = halógenos")
    print("   - Ayuda a predecir el comportamiento químico.\n")
    
    print("PERIODO:")
    print("   - Número de fila en la tabla periódica (1-7).")
    print("   - Indica el nivel de energía más externo de los electrones.")
    print("   - Ejemplo: El sodio (Na) está en el periodo 3")
    print("   - Relacionado con el tamaño del átomo.\n")

    print("ELECTRONEGATIVIDAD:")
    print("   - Medida de la capacidad de un átomo para atraer electrones (escala de Pauling).")
    print("   - Valores van desde ~0.7 (menos electronegativo) hasta 4.0 (más electronegativo).")
    print("   - Ejemplo: El flúor es el más electronegativo (3.98)")
    print("   - Determina el tipo de enlace químico que formará.\n")
    
    print("ESTADO A 25°C:")
    print("   - Estado físico del elemento a temperatura ambiente (25°C o 298K).")
    print("   - Puede ser: sólido, líquido o gas.")
    print("   - Ejemplo: El mercurio es líquido a 25°C")
    print("   - Información práctica sobre las condiciones normales.\n")
    

    print("TIPO:")
    print("    - Clasificación general del elemento:")
    print("      - Metales: Buenos conductores, maleables")
    print("      - No metales: Malos conductores, frágiles")
    print("      - Metaloides: Propiedades intermedias")
    print("      - Gases nobles: No reactivos")
    print("      - Halógenos: Muy reactivos")
    print("    - Ejemplo: El silicio es un metaloide\n")
    


def mostrar_bienvenida():
    print("\n" + "="*50)
    print(" BIENVENIDO A LA TABLA PERIÓDICA INTERACTIVA ")
    print("="*50)
    print("\n¿Qué es la tabla periódica?")
    print("La tabla periódica es como el 'catálogo universal' que organiza")
    print("todos los elementos químicos que forman todo lo que nos rodea:")
    print("- El aire que respiramos (Oxígeno, Nitrógeno)")
    print("- Los metales (Hierro, Cobre, Oro)")
    print("- Los componentes de los seres vivos (Carbono, Hidrógeno)")
    print("\nCada elemento tiene propiedades únicas y se organizan:")
    print("- Por FILAS (períodos) que indican niveles de energía")
    print("- Por COLUMNAS (grupos) que muestran propiedades similares")
    print("\nCada elemento tiene:")
    print("- Un nombre (como Hierro)")
    print("- Un símbolo (como Fe)")
    print("- Un número atómico (su 'DNI')")
    print("- Propiedades únicas")
def explicar_division():
    print("\n" + "="*50)
    print("📚 ORGANIZACIÓN DE LA TABLA PERIÓDICA 📚")
    print("="*50)
    print("\n* METALES (75% de los elementos):")
    print("- Brillantes, buenos conductores de calor/electricidad")
    print("- Maleables (se pueden deformar sin romperse)")
    print("- Ejemplos: Aluminio (latas), Hierro (construcción), Oro (joyería)")
    
    print("\n* NO METALES (derecha de la tabla):")
    print("- No son brillantes, malos conductores")
    print("- Frágiles en estado sólido")
    print("- Ejemplos: Oxígeno (respiración), Carbono (diamantes/grafito)")
    
    print("\n* METALOIDES (línea diagonal):")
    print("- Propiedades intermedias entre metales y no metales")
    print("- Semiconductores (usados en electrónica)")
    print("- Ejemplo: Silicio (chips de computadora)")
    
    print("\n* GASES NOBLES (última columna):")
    print("- Extremadamente estables, no reaccionan fácilmente")
    print("- Ejemplos: Helio (globos), Neón (luces)")
    
    print("\n* GRUPOS IMPORTANTES:")
    print("- Grupo 1: Metales alcalinos (muy reactivos)")
    print("- Grupo 2: Metales alcalinotérreos")
    print("- Grupos 3-12: Metales de transición")
    print("- Grupo 17: Halógenos (forman sales)")
    print("- Grupo 18: Gases nobles")

def buscar_elemento():
    
        print("\n" + "="*55)
        print("🔍 BUSCAR ELEMENTO QUÍMICO 🔍")
        print("="*55)
        print("1. Buscar por nombre (ej: hierro, oxígeno)")
        print("2. Buscar por símbolo (ej: Fe, O)")
        print("3. Buscar por número atómico (ej: 26, 8)")
        print("4. Volver al menú principal")
        
        opcion = input("\nElige cómo quieres buscar (1-4): ")
        
        if opcion == "1":
            nombre = input("Ingresa el nombre del elemento: ").strip().lower()
            encontrado = False
            for num, datos in elementos.items():
                if datos["nombre"].lower() == nombre:
                    mostrar_info_elemento(num)
                    encontrado = True
                    break

            if not encontrado:
                print(" Elemento no encontrado. Intenta con otro nombre o verifica la ortografía.")
        
        elif opcion == "2":
            simbolo = input("Ingresa el símbolo del elemento: ").strip().upper()
            encontrado = False
            for num, datos in elementos.items():
                if datos["simbolo"].upper() == simbolo:
                    mostrar_info_elemento(num)
                    encontrado = True
                    break
            if not encontrado:
                print(" Símbolo no válido. Recuerda que los símbolos tienen 1-2 letras (ej: Fe, O, Na)")
        
        elif opcion == "3":
            try:
                numero = int(input("Ingresa el número atómico (1-118): "))
                if numero in elementos:
                    mostrar_info_elemento(numero)
                else:
                    print(" Número atómico no disponible. La tabla periódica actual tiene 118 elementos.")
            except ValueError:
                print(" Debes ingresar un número entero (ej: 26 para el hierro)")
        
        elif opcion == "4":
            menu()
        
        else:
            print(" Opción no válida. Por favor elige del 1 al 4.")
            input("\nPresiona Enter para continuar...")

def mostrar_info_elemento(numero_atomico):
    e = elementos[numero_atomico]
    print("\n" + "----------------------------------------")
    print(f"📊 INFORMACIÓN COMPLETA DE: {e['nombre'].upper()} ({e['simbolo']})")
    print("-------------------------------------------")
    print(f"🔢 Número atómico: {numero_atomico}")
    print(f"⚖️ Masa atómica: {e['masa']} u")
    print(f"📊 Grupo: {e['grupo']} | Período: {e['periodo']}")
    print(f"📌 Tipo: {e['tipo']}")
    print(f"🌡 Estado a 25°C: {e['estado']}")
    if e['electronegatividad']:
        print(f"⚡ Electronegatividad: {e['electronegatividad']} (Pauling)")
    else:
        print("⚡ Electronegatividad: No aplica N/A")
    

elementos = {
    1: {"nombre": "Hidrógeno", "simbolo": "H", "grupo": 1, "periodo": 1, "tipo": "No metal", "estado": "Gas", "masa": 1.008, "electronegatividad": 2.20},
    2: {"nombre": "Helio", "simbolo": "He", "grupo": 18, "periodo": 1, "tipo": "Gas noble", "estado": "Gas", "masa": 4.0026, "electronegatividad": None},
    3: {"nombre": "Litio", "simbolo": "Li", "grupo": 1, "periodo": 2, "tipo": "Metal alcalino", "estado": "Sólido", "masa": 6.94, "electronegatividad": 0.98},
    4: {"nombre": "Berilio", "simbolo": "Be", "grupo": 2, "periodo": 2, "tipo": "Metal alcalinotérreo", "estado": "Sólido", "masa": 9.0122, "electronegatividad": 1.57},
    5: {"nombre": "Boro", "simbolo": "B", "grupo": 13, "periodo": 2, "tipo": "Metaloide", "estado": "Sólido", "masa": 10.81, "electronegatividad": 2.04},
    6: {"nombre": "Carbono", "simbolo": "C", "grupo": 14, "periodo": 2, "tipo": "No metal", "estado": "Sólido", "masa": 12.011, "electronegatividad": 2.55},
    7: {"nombre": "Nitrógeno", "simbolo": "N", "grupo": 15, "periodo": 2, "tipo": "No metal", "estado": "Gas", "masa": 14.007, "electronegatividad": 3.04},
    8: {"nombre": "Oxígeno", "simbolo": "O", "grupo": 16, "periodo": 2, "tipo": "No metal", "estado": "Gas", "masa": 15.999, "electronegatividad": 3.44},
    9: {"nombre": "Flúor", "simbolo": "F", "grupo": 17, "periodo": 2, "tipo": "Halógeno", "estado": "Gas", "masa": 18.998, "electronegatividad": 3.98},
    10: {"nombre": "Neón", "simbolo": "Ne", "grupo": 18, "periodo": 2, "tipo": "Gas noble", "estado": "Gas", "masa": 20.180, "electronegatividad": None},
    
    # Periodo 3
    11: {"nombre": "Sodio", "simbolo": "Na", "grupo": 1, "periodo": 3, "tipo": "Metal alcalino", "estado": "Sólido", "masa": 22.990, "electronegatividad": 0.93},
    12: {"nombre": "Magnesio", "simbolo": "Mg", "grupo": 2, "periodo": 3, "tipo": "Metal alcalinotérreo", "estado": "Sólido", "masa": 24.305, "electronegatividad": 1.31},
    13: {"nombre": "Aluminio", "simbolo": "Al", "grupo": 13, "periodo": 3, "tipo": "Metal", "estado": "Sólido", "masa": 26.982, "electronegatividad": 1.61},
    14: {"nombre": "Silicio", "simbolo": "Si", "grupo": 14, "periodo": 3, "tipo": "Metaloide", "estado": "Sólido", "masa": 28.085, "electronegatividad": 1.90},
    15: {"nombre": "Fósforo", "simbolo": "P", "grupo": 15, "periodo": 3, "tipo": "No metal", "estado": "Sólido", "masa": 30.974, "electronegatividad": 2.19},
    16: {"nombre": "Azufre", "simbolo": "S", "grupo": 16, "periodo": 3, "tipo": "No metal", "estado": "Sólido", "masa": 32.06, "electronegatividad": 2.58},
    17: {"nombre": "Cloro", "simbolo": "Cl", "grupo": 17, "periodo": 3, "tipo": "Halógeno", "estado": "Gas", "masa": 35.45, "electronegatividad": 3.16},
    18: {"nombre": "Argón", "simbolo": "Ar", "grupo": 18, "periodo": 3, "tipo": "Gas noble", "estado": "Gas", "masa": 39.948, "electronegatividad": None},
    
    # Periodo 4
    19: {"nombre": "Potasio", "simbolo": "K", "grupo": 1, "periodo": 4, "tipo": "Metal alcalino", "estado": "Sólido", "masa": 39.098, "electronegatividad": 0.82},
    20: {"nombre": "Calcio", "simbolo": "Ca", "grupo": 2, "periodo": 4, "tipo": "Metal alcalinotérreo", "estado": "Sólido", "masa": 40.078, "electronegatividad": 1.00},
    21: {"nombre": "Escandio", "simbolo": "Sc", "grupo": 3, "periodo": 4, "tipo": "Metal de transición", "estado": "Sólido", "masa": 44.956, "electronegatividad": 1.36},
    22: {"nombre": "Titanio", "simbolo": "Ti", "grupo": 4, "periodo": 4, "tipo": "Metal de transición", "estado": "Sólido", "masa": 47.867, "electronegatividad": 1.54},
    23: {"nombre": "Vanadio", "simbolo": "V", "grupo": 5, "periodo": 4, "tipo": "Metal de transición", "estado": "Sólido", "masa": 50.942, "electronegatividad": 1.63},
    24: {"nombre": "Cromo", "simbolo": "Cr", "grupo": 6, "periodo": 4, "tipo": "Metal de transición", "estado": "Sólido", "masa": 51.996, "electronegatividad": 1.66},
    25: {"nombre": "Manganeso", "simbolo": "Mn", "grupo": 7, "periodo": 4, "tipo": "Metal de transición", "estado": "Sólido", "masa": 54.938, "electronegatividad": 1.55},
    26: {"nombre": "Hierro", "simbolo": "Fe", "grupo": 8, "periodo": 4, "tipo": "Metal de transición", "estado": "Sólido", "masa": 55.845, "electronegatividad": 1.83},
    27: {"nombre": "Cobalto", "simbolo": "Co", "grupo": 9, "periodo": 4, "tipo": "Metal de transición", "estado": "Sólido", "masa": 58.933, "electronegatividad": 1.88},
    28: {"nombre": "Níquel", "simbolo": "Ni", "grupo": 10, "periodo": 4, "tipo": "Metal de transición", "estado": "Sólido", "masa": 58.693, "electronegatividad": 1.91},
    29: {"nombre": "Cobre", "simbolo": "Cu", "grupo": 11, "periodo": 4, "tipo": "Metal de transición", "estado": "Sólido", "masa": 63.546, "electronegatividad": 1.90},
    30: {"nombre": "Zinc", "simbolo": "Zn", "grupo": 12, "periodo": 4, "tipo": "Metal de transición", "estado": "Sólido", "masa": 65.38, "electronegatividad": 1.65},
    31: {"nombre": "Galio", "simbolo": "Ga", "grupo": 13, "periodo": 4, "tipo": "Metal", "estado": "Sólido", "masa": 69.723, "electronegatividad": 1.81},
    32: {"nombre": "Germanio", "simbolo": "Ge", "grupo": 14, "periodo": 4, "tipo": "Metaloide", "estado": "Sólido", "masa": 72.630, "electronegatividad": 2.01},
    33: {"nombre": "Arsénico", "simbolo": "As", "grupo": 15, "periodo": 4, "tipo": "Metaloide", "estado": "Sólido", "masa": 74.922, "electronegatividad": 2.18},
    34: {"nombre": "Selenio", "simbolo": "Se", "grupo": 16, "periodo": 4, "tipo": "No metal", "estado": "Sólido", "masa": 78.971, "electronegatividad": 2.55},
    35: {"nombre": "Bromo", "simbolo": "Br", "grupo": 17, "periodo": 4, "tipo": "Halógeno", "estado": "Líquido", "masa": 79.904, "electronegatividad": 2.96},
    36: {"nombre": "Kriptón", "simbolo": "Kr", "grupo": 18, "periodo": 4, "tipo": "Gas noble", "estado": "Gas", "masa": 83.798, "electronegatividad": 3.00},
    # Periodo 5
    37: {"nombre": "Rubidio", "simbolo": "Rb", "grupo": 1, "periodo": 5, "tipo": "Metal alcalino", "estado": "Sólido", "masa": 85.468, "electronegatividad": 0.82},
    38: {"nombre": "Estroncio", "simbolo": "Sr", "grupo": 2, "periodo": 5, "tipo": "Metal alcalinotérreo", "estado": "Sólido", "masa": 87.62, "electronegatividad": 0.95},
    39: {"nombre": "Itrio", "simbolo": "Y", "grupo": 3, "periodo": 5, "tipo": "Metal de transición", "estado": "Sólido", "masa": 88.906, "electronegatividad": 1.22},
    40: {"nombre": "Circonio", "simbolo": "Zr", "grupo": 4, "periodo": 5, "tipo": "Metal de transición", "estado": "Sólido", "masa": 91.224, "electronegatividad": 1.33},
    41: {"nombre": "Niobio", "simbolo": "Nb", "grupo": 5, "periodo": 5, "tipo": "Metal de transición", "estado": "Sólido", "masa": 92.906, "electronegatividad": 1.6},
    42: {"nombre": "Molibdeno", "simbolo": "Mo", "grupo": 6, "periodo": 5, "tipo": "Metal de transición", "estado": "Sólido", "masa": 95.95, "electronegatividad": 2.16},
    43: {"nombre": "Tecnecio", "simbolo": "Tc", "grupo": 7, "periodo": 5, "tipo": "Metal de transición", "estado": "Sólido", "masa": 98, "electronegatividad": 1.9},
    44: {"nombre": "Rutenio", "simbolo": "Ru", "grupo": 8, "periodo": 5, "tipo": "Metal de transición", "estado": "Sólido", "masa": 101.07, "electronegatividad": 2.2},
    45: {"nombre": "Rodio", "simbolo": "Rh", "grupo": 9, "periodo": 5, "tipo": "Metal de transición", "estado": "Sólido", "masa": 102.91, "electronegatividad": 2.28},
    46: {"nombre": "Paladio", "simbolo": "Pd", "grupo": 10, "periodo": 5, "tipo": "Metal de transición", "estado": "Sólido", "masa": 106.42, "electronegatividad": 2.20},
    47: {"nombre": "Plata", "simbolo": "Ag", "grupo": 11, "periodo": 5, "tipo": "Metal de transición", "estado": "Sólido", "masa": 107.87, "electronegatividad": 1.93},
    48: {"nombre": "Cadmio", "simbolo": "Cd", "grupo": 12, "periodo": 5, "tipo": "Metal de transición", "estado": "Sólido", "masa": 112.41, "electronegatividad": 1.69},
    49: {"nombre": "Indio", "simbolo": "In", "grupo": 13, "periodo": 5, "tipo": "Metal", "estado": "Sólido", "masa": 114.82, "electronegatividad": 1.78},
    50: {"nombre": "Estaño", "simbolo": "Sn", "grupo": 14, "periodo": 5, "tipo": "Metal", "estado": "Sólido", "masa": 118.71, "electronegatividad": 1.96},
    51: {"nombre": "Antimonio", "simbolo": "Sb", "grupo": 15, "periodo": 5, "tipo": "Metaloide", "estado": "Sólido", "masa": 121.76, "electronegatividad": 2.05},
    52: {"nombre": "Telurio", "simbolo": "Te", "grupo": 16, "periodo": 5, "tipo": "Metaloide", "estado": "Sólido", "masa": 127.60, "electronegatividad": 2.1},
    53: {"nombre": "Yodo", "simbolo": "I", "grupo": 17, "periodo": 5, "tipo": "Halógeno", "estado": "Sólido", "masa": 126.90, "electronegatividad": 2.66},
    54: {"nombre": "Xenón", "simbolo": "Xe", "grupo": 18, "periodo": 5, "tipo": "Gas noble", "estado": "Gas", "masa": 131.29, "electronegatividad": 2.6},

    # Periodo 6
    55: {"nombre": "Cesio", "simbolo": "Cs", "grupo": 1, "periodo": 6, "tipo": "Metal alcalino", "estado": "Sólido", "masa": 132.91, "electronegatividad": 0.79},
    56: {"nombre": "Bario", "simbolo": "Ba", "grupo": 2, "periodo": 6, "tipo": "Metal alcalinotérreo", "estado": "Sólido", "masa": 137.33, "electronegatividad": 0.89},
    57: {"nombre": "Lantano", "simbolo": "La", "grupo": 3, "periodo": 6, "tipo": "Lantánido", "estado": "Sólido", "masa": 138.91, "electronegatividad": 1.10},
    58: {"nombre": "Cerio", "simbolo": "Ce", "grupo": None, "periodo": 6, "tipo": "Lantánido", "estado": "Sólido", "masa": 140.12, "electronegatividad": 1.12},
    59: {"nombre": "Praseodimio", "simbolo": "Pr", "grupo": None, "periodo": 6, "tipo": "Lantánido", "estado": "Sólido", "masa": 140.91, "electronegatividad": 1.13},
    60: {"nombre": "Neodimio", "simbolo": "Nd", "grupo": None, "periodo": 6, "tipo": "Lantánido", "estado": "Sólido", "masa": 144.24, "electronegatividad": 1.14},
    61: {"nombre": "Prometio", "simbolo": "Pm", "grupo": None, "periodo": 6, "tipo": "Lantánido", "estado": "Sólido", "masa": 145, "electronegatividad": 1.13},
    62: {"nombre": "Samario", "simbolo": "Sm", "grupo": None, "periodo": 6, "tipo": "Lantánido", "estado": "Sólido", "masa": 150.36, "electronegatividad": 1.17},
    63: {"nombre": "Europio", "simbolo": "Eu", "grupo": None, "periodo": 6, "tipo": "Lantánido", "estado": "Sólido", "masa": 151.96, "electronegatividad": 1.2},
    64: {"nombre": "Gadolinio", "simbolo": "Gd", "grupo": None, "periodo": 6, "tipo": "Lantánido", "estado": "Sólido", "masa": 157.25, "electronegatividad": 1.2},
    65: {"nombre": "Terbio", "simbolo": "Tb", "grupo": None, "periodo": 6, "tipo": "Lantánido", "estado": "Sólido", "masa": 158.93, "electronegatividad": 1.2},
    66: {"nombre": "Disprosio", "simbolo": "Dy", "grupo": None, "periodo": 6, "tipo": "Lantánido", "estado": "Sólido", "masa": 162.50, "electronegatividad": 1.22},
    67: {"nombre": "Holmio", "simbolo": "Ho", "grupo": None, "periodo": 6, "tipo": "Lantánido", "estado": "Sólido", "masa": 164.93, "electronegatividad": 1.23},
    68: {"nombre": "Erbio", "simbolo": "Er", "grupo": None, "periodo": 6, "tipo": "Lantánido", "estado": "Sólido", "masa": 167.26, "electronegatividad": 1.24},
    69: {"nombre": "Tulio", "simbolo": "Tm", "grupo": None, "periodo": 6, "tipo": "Lantánido", "estado": "Sólido", "masa": 168.93, "electronegatividad": 1.25},
    70: {"nombre": "Iterbio", "simbolo": "Yb", "grupo": None, "periodo": 6, "tipo": "Lantánido", "estado": "Sólido", "masa": 173.05, "electronegatividad": 1.1},
    71: {"nombre": "Lutecio", "simbolo": "Lu", "grupo": 3, "periodo": 6, "tipo": "Lantánido", "estado": "Sólido", "masa": 174.97, "electronegatividad": 1.27},
    72: {"nombre": "Hafnio", "simbolo": "Hf", "grupo": 4, "periodo": 6, "tipo": "Metal de transición", "estado": "Sólido", "masa": 178.49, "electronegatividad": 1.3},
    73: {"nombre": "Tantalio", "simbolo": "Ta", "grupo": 5, "periodo": 6, "tipo": "Metal de transición", "estado": "Sólido", "masa": 180.95, "electronegatividad": 1.5},
    74: {"nombre": "Wolframio", "simbolo": "W", "grupo": 6, "periodo": 6, "tipo": "Metal de transición", "estado": "Sólido", "masa": 183.84, "electronegatividad": 2.36},
    75: {"nombre": "Renio", "simbolo": "Re", "grupo": 7, "periodo": 6, "tipo": "Metal de transición", "estado": "Sólido", "masa": 186.21, "electronegatividad": 1.9},
    76: {"nombre": "Osmio", "simbolo": "Os", "grupo": 8, "periodo": 6, "tipo": "Metal de transición", "estado": "Sólido", "masa": 190.23, "electronegatividad": 2.2},
    77: {"nombre": "Iridio", "simbolo": "Ir", "grupo": 9, "periodo": 6, "tipo": "Metal de transición", "estado": "Sólido", "masa": 192.22, "electronegatividad": 2.20},
    78: {"nombre": "Platino", "simbolo": "Pt", "grupo": 10, "periodo": 6, "tipo": "Metal de transición", "estado": "Sólido", "masa": 195.08, "electronegatividad": 2.28},
    79: {"nombre": "Oro", "simbolo": "Au", "grupo": 11, "periodo": 6, "tipo": "Metal de transición", "estado": "Sólido", "masa": 196.97, "electronegatividad": 2.54},
    80: {"nombre": "Mercurio", "simbolo": "Hg", "grupo": 12, "periodo": 6, "tipo": "Metal de transición", "estado": "Líquido", "masa": 200.59, "electronegatividad": 2.00},
    81: {"nombre": "Talio", "simbolo": "Tl", "grupo": 13, "periodo": 6, "tipo": "Metal", "estado": "Sólido", "masa": 204.38, "electronegatividad": 1.62},
    82: {"nombre": "Plomo", "simbolo": "Pb", "grupo": 14, "periodo": 6, "tipo": "Metal", "estado": "Sólido", "masa": 207.2, "electronegatividad": 2.33},
    83: {"nombre": "Bismuto", "simbolo": "Bi", "grupo": 15, "periodo": 6, "tipo": "Metal", "estado": "Sólido", "masa": 208.98, "electronegatividad": 2.02},
    84: {"nombre": "Polonio", "simbolo": "Po", "grupo": 16, "periodo": 6, "tipo": "Metal", "estado": "Sólido", "masa": 209, "electronegatividad": 2.0},
    85: {"nombre": "Ástato", "simbolo": "At", "grupo": 17, "periodo": 6, "tipo": "Halógeno", "estado": "Sólido", "masa": 210, "electronegatividad": 2.2},
    86: {"nombre": "Radón", "simbolo": "Rn", "grupo": 18, "periodo": 6, "tipo": "Gas noble", "estado": "Gas", "masa": 222, "electronegatividad": None},

    # Periodo 7
    87: {"nombre": "Francio", "simbolo": "Fr", "grupo": 1, "periodo": 7, "tipo": "Metal alcalino", "estado": "Sólido", "masa": 223, "electronegatividad": 0.7},
    88: {"nombre": "Radio", "simbolo": "Ra", "grupo": 2, "periodo": 7, "tipo": "Metal alcalinotérreo", "estado": "Sólido", "masa": 226, "electronegatividad": 0.9},
    89: {"nombre": "Actinio", "simbolo": "Ac", "grupo": 3, "periodo": 7, "tipo": "Actínido", "estado": "Sólido", "masa": 227, "electronegatividad": 1.1},
    90: {"nombre": "Torio", "simbolo": "Th", "grupo": None, "periodo": 7, "tipo": "Actínido", "estado": "Sólido", "masa": 232.04, "electronegatividad": 1.3},
    91: {"nombre": "Protactinio", "simbolo": "Pa", "grupo": None, "periodo": 7, "tipo": "Actínido", "estado": "Sólido", "masa": 231.04, "electronegatividad": 1.5},
    92: {"nombre": "Uranio", "simbolo": "U", "grupo": None, "periodo": 7, "tipo": "Actínido", "estado": "Sólido", "masa": 238.03, "electronegatividad": 1.38},
    93: {"nombre": "Neptunio", "simbolo": "Np", "grupo": None, "periodo": 7, "tipo": "Actínido", "estado": "Sólido", "masa": 237, "electronegatividad": 1.36},
    94: {"nombre": "Plutonio", "simbolo": "Pu", "grupo": None, "periodo": 7, "tipo": "Actínido", "estado": "Sólido", "masa": 244, "electronegatividad": 1.28},
    95: {"nombre": "Americio", "simbolo": "Am", "grupo": None, "periodo": 7, "tipo": "Actínido", "estado": "Sólido", "masa": 243, "electronegatividad": 1.13},
    96: {"nombre": "Curio", "simbolo": "Cm", "grupo": None, "periodo": 7, "tipo": "Actínido", "estado": "Sólido", "masa": 247, "electronegatividad": 1.28},
    97: {"nombre": "Berkelio", "simbolo": "Bk", "grupo": None, "periodo": 7, "tipo": "Actínido", "estado": "Sólido", "masa": 247, "electronegatividad": 1.3},
    98: {"nombre": "Californio", "simbolo": "Cf", "grupo": None, "periodo": 7, "tipo": "Actínido", "estado": "Sólido", "masa": 251, "electronegatividad": 1.3},
    99: {"nombre": "Einstenio", "simbolo": "Es", "grupo": None, "periodo": 7, "tipo": "Actínido", "estado": "Sólido", "masa": 252, "electronegatividad": 1.3},
    100: {"nombre": "Fermio", "simbolo": "Fm", "grupo": None, "periodo": 7, "tipo": "Actínido", "estado": "Sólido", "masa": 257, "electronegatividad": 1.3},
    101: {"nombre": "Mendelevio", "simbolo": "Md", "grupo": None, "periodo": 7, "tipo": "Actínido", "estado": "Sólido", "masa": 258, "electronegatividad": 1.3},
    102: {"nombre": "Nobelio", "simbolo": "No", "grupo": None, "periodo": 7, "tipo": "Actínido", "estado": "Sólido", "masa": 259, "electronegatividad": 1.3},
    103: {"nombre": "Lawrencio", "simbolo": "Lr", "grupo": 3, "periodo": 7, "tipo": "Actínido", "estado": "Sólido", "masa": 262, "electronegatividad": 1.3},
    104: {"nombre": "Rutherfordio", "simbolo": "Rf", "grupo": 4, "periodo": 7, "tipo": "Metal de transición", "estado": "Desconocido", "masa": 261, "electronegatividad": None},
    105: {"nombre": "Dubnio", "simbolo": "Db", "grupo": 5, "periodo": 7, "tipo": "Metal de transición", "estado": "Desconocido", "masa": 262, "electronegatividad": None},
    106: {"nombre": "Seaborgio", "simbolo": "Sg", "grupo": 6, "periodo": 7, "tipo": "Metal de transición", "estado": "Desconocido", "masa": 266, "electronegatividad": None},
    107: {"nombre": "Bohrio", "simbolo": "Bh", "grupo": 7, "periodo": 7, "tipo": "Metal de transición", "estado": "Desconocido", "masa": 264, "electronegatividad": None},
    108: {"nombre": "Hassio", "simbolo": "Hs", "grupo": 8, "periodo": 7, "tipo": "Metal de transición", "estado": "Desconocido", "masa": 277, "electronegatividad": None},
    109: {"nombre": "Meitnerio", "simbolo": "Mt", "grupo": 9, "periodo": 7, "tipo": "N/A", "estado": "Desconocido", "masa": 268, "electronegatividad": None},
    110: {"nombre": "Darmstatio", "simbolo": "Ds", "grupo": 10, "periodo": 7, "tipo": "N/A", "estado": "Desconocido", "masa": 281, "electronegatividad": None},
    111: {"nombre": "Roentgenio", "simbolo": "Rg", "grupo": 11, "periodo": 7, "tipo": "N/A", "estado": "Desconocido", "masa": 282, "electronegatividad": None},
    112: {"nombre": "Copernicio", "simbolo": "Cn", "grupo": 12, "periodo": 7, "tipo": "N/A", "estado": "Desconocido", "masa": 285, "electronegatividad": None},
    113: {"nombre": "Nihonio", "simbolo": "Nh", "grupo": 13, "periodo": 7, "tipo": "N/A", "estado": "Desconocido", "masa": 286, "electronegatividad": None},
    114: {"nombre": "Flerovio", "simbolo": "Fl", "grupo": 14, "periodo": 7, "tipo": "N/A", "estado": "Desconocido", "masa": 289, "electronegatividad": None},
    115: {"nombre": "Moscovio", "simbolo": "Mc", "grupo": 15, "periodo": 7, "tipo": "N/A", "estado": "Desconocido", "masa": 290, "electronegatividad": None},
    116: {"nombre": "Livermorio", "simbolo": "Lv", "grupo": 16, "periodo": 7, "tipo": "N/A", "estado": "Desconocido", "masa": 293, "electronegatividad": None},
    117: {"nombre": "Teneso", "simbolo": "Ts", "grupo": 17, "periodo": 7, "tipo": "N/A", "estado": "Desconocido", "masa": 294, "electronegatividad": None},
    118: {"nombre": "Oganesón", "simbolo": "Og", "grupo": 18, "periodo": 7, "tipo": "N/A", "estado": "Desconocido", "masa": 294, "electronegatividad": None}

}
menu()
# Out:
# ...
# ----------------------------------------------------
# ----🧪🧪TABLA PERIÓDICA DE LOS ELEMENTOS🧪🧪------
# ----------------------------------------------------
#
# ...
# 1. ¿Qué es la tabla periódica?📖
# 2. ¿Cómo se divide la tabla?🧩
# 3. Explicación de los datos (recomendado antes de buscar la información de un elemento)📖
# 4. Buscar información de un elemento🔍
# 5. Salir🚪
# Elige una opción (1-4):  4
# ...
# 🔍 BUSCAR ELEMENTO QUÍMICO 🔍
# ...
# 1. Buscar por nombre (ej: hierro, oxígeno)
# 2. Buscar por símbolo (ej: Fe, O)
# 3. Buscar por número atómico (ej: 26, 8)
# 4. Volver al menú principal
# Elige cómo quieres buscar (1-4):  3
# Ingresa el número atómico (1-118):  3
# ----------------------------------------
# 📊 INFORMACIÓN COMPLETA DE: LITIO (Li)
# -------------------------------------------
# 🔢 Número atómico: 3
# ⚖️ Masa atómica: 6.94 u
# 📊 Grupo: 1 | Período: 2
# 📌 Tipo: Metal alcalino
# 🌡 Estado a 25°C: Sólido
# ⚡ Electronegatividad: 0.98 (Pauling)
#  Si desea volver al menú ingrese 1: 1
# ...
